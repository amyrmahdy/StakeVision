# %%
import os
import dotenv
import pandas as pd
from reader import read_query
import matplotlib.pyplot as plt
from preprocessor import process_data

# %%
retrieved_rows = read_query('tonusdt.hourly')

# Preprocess
df = process_data(retrieved_rows)
# df.drop(['date','epoch','second'], axis = 1, inplace = True)
df.head()
# Out:
# Creating conncetion:
# Execute select query:
# Conncetion closed.
#            epoch    open    high     low   close      volume  \
# 0  1703120400000  2.2358  2.2403  2.2242  2.2313    6593.284
# 1  1703124000000  2.2312  2.2514  2.2276  2.2477   10110.758
# 2  1703127600000  2.2466  2.2936  2.2448  2.2848   20228.684
# 3  1703131200000  2.2806  2.3012  2.2766  2.2989   28864.896
# 4  1703134800000  2.2974  2.3173  2.2800  2.2800  103253.660
#
#                  date  year  month  day  hour  minute  second
# 0 2023-12-21 04:30:00  2023     12   21     4      30       0
# 1 2023-12-21 05:30:00  2023     12   21     5      30       0
# 2 2023-12-21 06:30:00  2023     12   21     6      30       0
# 3 2023-12-21 07:30:00  2023     12   21     7      30       0
# 4 2023-12-21 08:30:00  2023     12   21     8      30       0

# %%
df.plot(kind = 'line', x = 'date', y = 'close')
plt.show()
